# %% [markdown]
# # CBSE Class 11 Python - Beginner Level Questions
# This notebook contains 10 basic Python programming questions aligned with the Sumita Arora textbook for Class 11.
#
# ---
# ## Question 1: Hello World
# Write a program to print "Hello, Python!" and your name.

# %% [markdown]
# ---
# ## Question 2: Sum of Two Numbers
# Write a program to calculate the sum of two numbers entered by the user.

# %% [markdown]
# ---
# ## Question 3: Area of a Circle
# Write a program to find the area and circumference of a circle given its radius.

# %% [markdown]
# ---
# ## Question 4: Simple Interest
# Write a program to calculate Simple Interest (P*R*T/100).

# %% [markdown]
# ---
# ## Question 5: Even or Odd
# Write a program to check whether a number is even or odd.

# %% [markdown]
# ---
# ## Question 6: Largest of Two Numbers
# Write a program to find the largest of two numbers.

# %% [markdown]
# ---
# ## Question 7: Temperature Conversion
# Write a program to convert temperature from Celsius to Fahrenheit.

# %% [markdown]
# ---
# ## Question 8: Swap Two Numbers
# Write a program to swap the values of two variables.

# %% [markdown]
# ---
# ## Question 9: Leap Year Check
# Write a program to check if a year is a leap year or not.

# %% [markdown]
# ---
# ## Question 10: First 10 Natural Numbers
# Write a program to print the first 10 natural numbers using a `for` loop.
