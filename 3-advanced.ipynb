# %% [markdown]
# # CBSE Class 11 Python - Advanced Level Questions
# This notebook contains 10 advanced Python programming questions focusing on algorithms, data structures, and logic building.
#
# ---
# ## Question 21: Bubble Sort
# Write a program to sort a list of numbers using the Bubble Sort algorithm.

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

numbers = [64, 34, 25, 12, 22, 11, 90]
print("Original list:", numbers)
bubble_sort(numbers)
print("Sorted list:", numbers)

# %% [markdown]
# ---
# ## Question 22: Linear Search
# Write a program to search for a specific element in a list using Linear Search.

# %%
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1

numbers = [10, 20, 30, 40, 50]
target = 30
result = linear_search(numbers, target)

if result != -1:
    print("Element found at index:", result)
else:
    print("Element not found")

# %% [markdown]
# ---
# ## Question 23: Binary Search
# Write a program to search for a specific element in a sorted list using Binary Search.

# %%
def binary_search(arr, low, high, x):
    if high >= low:
        mid = (high + low) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
        else:
            return binary_search(arr, mid + 1, high, x)
    else:
        return -1

numbers = [10, 20, 30, 40, 50]
target = 40
result = binary_search(numbers, 0, len(numbers) - 1, target)

if result != -1:
    print("Element found at index:", result)
else:
    print("Element not found")

# %% [markdown]
# ---
# ## Question 24: Matrix Addition
# Write a program to add two 2x2 matrices.

# %%
X = [[1, 2],
     [3, 4]]

Y = [[5, 6],
     [7, 8]]

result = [[0, 0],
          [0, 0]]

for i in range(len(X)):
    for j in range(len(X[0])):
        result[i][j] = X[i][j] + Y[i][j]

print("Resultant Matrix:")
for r in result:
    print(r)

# %% [markdown]
# ---
# ## Question 25: Pattern Printing
# Write a program to print the following pattern using nested loops:
# ```
# *
# **
# ***
# ****
# *****
# ```

# %%
rows = 5
for i in range(1, rows + 1):
    for j in range(1, i + 1):
        print("*", end="")
    print()

# %% [markdown]
# ---
# ## Question 26: Character Frequency
# Write a program to find the frequency of each character in a string using a dictionary.

# %%
string = "hello world"
freq = {}

for char in string:
    if char in freq:
        freq[char] += 1
    else:
        freq[char] = 1

print("Character frequencies:", freq)

# %% [markdown]
# ---
# ## Question 27: Second Largest Number
# Write a program to find the second largest number in a list.

# %%
numbers = [10, 20, 4, 45, 99]
numbers.sort()
print("The second largest element is:", numbers[-2])

# %% [markdown]
# ---
# ## Question 28: List Comprehension
# Write a program to create a list of squares of even numbers from 1 to 10 using list comprehension.

# %%
squares = [x**2 for x in range(1, 11) if x % 2 == 0]
print("Squares of even numbers:", squares)

# %% [markdown]
# ---
# ## Question 29: Nested Dictionary
# Write a program to store information about 3 employees (Name, ID, Salary) in a nested dictionary and print the details of the employee with the highest salary.

# %%
employees = {
    101: {"name": "John", "salary": 50000},
    102: {"name": "Jane", "salary": 60000},
    103: {"name": "Doe", "salary": 55000}
}

max_salary = 0
top_employee = None

for emp_id, details in employees.items():
    if details["salary"] > max_salary:
        max_salary = details["salary"]
        top_employee = details

print("Employee with highest salary:", top_employee)

# %% [markdown]
# ---
# ## Question 30: Simple File Handling
# Write a program to create a text file named `test.txt`, write "Hello, this is a test file." into it, and then read and print the content of the file.

# %%
# Writing to a file
with open("test.txt", "w") as f:
    f.write("Hello, this is a test file.")

# Reading from a file
with open("test.txt", "r") as f:
    content = f.read()
    print("File content:", content)
